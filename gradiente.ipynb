# %% [markdown]
# <a href="https://colab.research.google.com/github/angel-ctrl/grad/blob/master/gradiente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
import scipy as sc
import pandas as pd

url = 'https://raw.githubusercontent.com/angel-ctrl/grad/master/train.csv'

data = pd.read_csv(url)

dataa = pd.DataFrame(data)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 15)

data["Age"] = data["Age"].replace(np.nan, int(np.mean(data["Age"])))

print(data["Age"])
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
# 5      29.00
# 6      54.00
# 7       2.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 12     20.00
# 13     39.00
# 14     14.00
# 15     55.00
# 16      2.00
# 17     29.00
# 18     31.00
# 19     29.00
# 20     35.00
# 21     34.00
# 22     15.00
# 23     28.00
# 24      8.00
# 25     38.00
# 26     29.00
# 27     19.00
# 28     29.00
# 29     29.00
# 30     40.00
# 31     29.00
# 32     29.00
# 33     66.00
# 34     28.00
# 35     42.00
# 36     29.00
# 37     21.00
# 38     18.00
# 39     14.00
# 40     40.00
# 41     27.00
# 42     29.00
# 43      3.00
# 44     19.00
# 45     29.00
# 46     29.00
# 47     29.00
# 48     29.00
# 49     18.00
# 50      7.00
# 51     21.00
# 52     49.00
# 53     29.00
# 54     65.00
# 55     29.00
# 56     21.00
# 57     28.50
# 58      5.00
# 59     11.00
# 60     22.00
# 61     38.00
# 62     45.00
# 63      4.00
# 64     29.00
# 65     29.00
# ...
